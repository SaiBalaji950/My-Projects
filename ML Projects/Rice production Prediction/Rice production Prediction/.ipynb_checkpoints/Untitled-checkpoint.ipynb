# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data.csv')
data
# Out:
#     Province  Year  Harvested Area  Production  Rainfall  Humidity  \
# 0       Aceh  2018          329516     1861567      2336        81
# 1       Aceh  2019          310012     1714438      1437        82
# 2       Aceh  2020          317869     1757313      1790        76
# 3       Aceh  2021          297058     1634640      2293        76
# 4       Aceh  2022          271750     1509456      1834        76
# ..       ...   ...             ...         ...       ...       ...
# 199    Papua  2019           54132      235340      1823        77
# 200    Papua  2020           52728      166002      1502        75
# 201    Papua  2021           64985      286280      2028        76
# 202    Papua  2022           49742      193944      2576        84
# 203    Papua  2023           49323      200115      2555        80
#
#      Temperature
# 0             28
# 1             27
# 2             29
# 3             29
# 4             29
# ..           ...
# 199           28
# ...

# %%
import pandas as pd
import numpy as np

provinces = ['Aceh', 'Sumatera Utara', 'Sumatera Barat', 'Riau', 'Jambi', 'Sumatera Selatan', 
             'Bengkulu', 'Lampung', 'Kepulauan Bangka Belitung', 'Kepulauan Riau', 'DKI Jakarta',
             'Jawa Barat', 'Jawa Tengah', 'DI Yogyakarta', 'Jawa Timur', 'Banten', 'Bali', 
             'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Kalimantan Barat', 'Kalimantan Tengah', 
             'Kalimantan Selatan', 'Kalimantan Timur', 'Kalimantan Utara', 'Sulawesi Utara', 
             'Sulawesi Tengah', 'Sulawesi Selatan', 'Sulawesi Tenggara', 'Gorontalo', 'Sulawesi Barat', 
             'Maluku', 'Maluku Utara', 'Papua Barat', 'Papua']

provinces = np.resize(provinces, 204)

data = pd.DataFrame({
    'Province': provinces,
    'Year': np.random.randint(2018, 2024, size=204), 
    'Harvested Area': np.random.uniform(100, 10000, size=204),
    'Production': np.random.uniform(500, 50000, size=204),
    'Rainfall': np.random.uniform(100, 3000, size=204),
    'Humidity': np.random.uniform(50, 100, size=204),
    'Temperature': np.random.uniform(20, 35, size=204)
})

expanded_data = data.sample(n=3660, replace=True, random_state=42)
expanded_data.to_csv('expanded_agriculture_data.csv', index=False)

# %%
data = pd.read_csv('expanded_agriculture_data.csv')
data
# Out:
#                  Province  Year  Harvested Area    Production     Rainfall  \
# 0                    Aceh  2019     1424.293464  25801.764898  2831.560841
# 1          Kepulauan Riau  2020     6114.751121  44626.209626  1722.777453
# 2          Sulawesi Utara  2019     1660.768043  21617.397809  1306.531621
# 3              Jawa Timur  2022     3793.726252  17354.810069  2873.744139
# 4                   Jambi  2023     3969.911095  25785.067184   324.781118
# ...                   ...   ...             ...           ...          ...
# 3655  Nusa Tenggara Timur  2018     8805.503426  10628.729763  2783.792600
# 3656           Jawa Timur  2018     3719.776568  12438.357384   439.951525
# 3657           Jawa Barat  2019     2981.478022  34566.552608   365.310355
# 3658          DKI Jakarta  2019     3439.102170   4198.449067  1807.079109
# 3659     Kalimantan Barat  2023      479.125959  37050.675986   377.820711
#
#        Humidity  Temperature
# 0     59.289787    28.910278
# ...

# %%
data.head()
# Out:
#          Province  Year  Harvested Area    Production     Rainfall   Humidity  \
# 0            Aceh  2019     1424.293464  25801.764898  2831.560841  59.289787
# 1  Kepulauan Riau  2020     6114.751121  44626.209626  1722.777453  62.244203
# 2  Sulawesi Utara  2019     1660.768043  21617.397809  1306.531621  95.417902
# 3      Jawa Timur  2022     3793.726252  17354.810069  2873.744139  54.669488
# 4           Jambi  2023     3969.911095  25785.067184   324.781118  67.921921
#
#    Temperature
# 0    28.910278
# 1    24.606217
# 2    27.800699
# 3    29.303221
# 4    20.928729

# %%
data.tail()
# Out:
#                  Province  Year  Harvested Area    Production     Rainfall  \
# 3655  Nusa Tenggara Timur  2018     8805.503426  10628.729763  2783.792600
# 3656           Jawa Timur  2018     3719.776568  12438.357384   439.951525
# 3657           Jawa Barat  2019     2981.478022  34566.552608   365.310355
# 3658          DKI Jakarta  2019     3439.102170   4198.449067  1807.079109
# 3659     Kalimantan Barat  2023      479.125959  37050.675986   377.820711
#
#        Humidity  Temperature
# 3655  79.582643    24.787319
# 3656  78.674428    30.863002
# 3657  60.881017    29.434494
# 3658  57.084987    24.803592
# 3659  55.616995    20.289727

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province        3660 non-null   object
#  1   Year            3660 non-null   int64
#  2   Harvested Area  3660 non-null   float64
#  3   Production      3660 non-null   float64
#  4   Rainfall        3660 non-null   float64
#  5   Humidity        3660 non-null   float64
#  6   Temperature     3660 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 200.3+ KB

# %%
data.describe()
# Out:
#               Year  Harvested Area    Production     Rainfall     Humidity  \
# count  3660.000000     3660.000000   3660.000000  3660.000000  3660.000000
# mean   2020.429235     4951.347189  22323.048197  1565.850164    76.220020
# std       1.673440     2850.774343  14044.918622   855.358818    14.500531
# min    2018.000000      143.247993    709.887583   104.293206    50.664710
# 25%    2019.000000     2372.082159   9677.640390   827.304284    63.048093
# 50%    2020.000000     4957.846283  21358.806135  1501.939533    76.329134
# 75%    2022.000000     7327.851724  33954.793727  2257.088222    89.329532
# max    2023.000000     9969.979407  49730.566154  2975.609995    99.914479
#
#        Temperature
# count  3660.000000
# mean     27.744380
# std       4.241943
# min      20.136599
# 25%      24.392649
# 50%      27.876370
# 75%      31.713733
# max      34.983342

# %%
data.shape
# Out:
# (3660, 7)

# %%
for i in data.columns:
    print(i)
    print(data[i].unique())
    print()
# Out:
# Province
# ['Aceh' 'Kepulauan Riau' 'Sulawesi Utara' 'Jawa Timur' 'Jambi' 'Riau'
#  'Nusa Tenggara Timur' 'Kalimantan Tengah' 'Kalimantan Barat' 'Bengkulu'
#  'Papua Barat' 'Maluku Utara' 'Sumatera Utara' 'Banten' 'Gorontalo'
#  'DI Yogyakarta' 'Kalimantan Selatan' 'Sulawesi Tenggara'
#  'Nusa Tenggara Barat' 'Papua' 'Kalimantan Utara' 'Bali'
#  'Sumatera Selatan' 'Sulawesi Barat' 'Maluku' 'Sulawesi Tengah'
#  'Kepulauan Bangka Belitung' 'Lampung' 'Jawa Tengah' 'Sulawesi Selatan'
#  'DKI Jakarta' 'Sumatera Barat' 'Jawa Barat' 'Kalimantan Timur']
#
# Year
# [2019 2020 2022 2023 2018 2021]
#
# Harvested Area
# [1424.29346385 6114.75112148 1660.76804303 3793.72625189 3969.91109453
#  9744.43866859 8805.50342634 2087.49107714 3832.21293733 5900.48911863
#  9600.74724524 5330.83734664 3441.32397599 3523.22080047 8682.72615428
#  2197.594954   6094.02876106 7482.27348684 5245.89828715 1369.40698716
#  8450.73358775 9427.78747728 6898.70232116 4449.78282246 4957.84628269
# ...

# %%
print(data["Province"].value_counts())
# Out:
# Sulawesi Tenggara            131
# Nusa Tenggara Barat          124
# Jawa Tengah                  122
# Lampung                      119
# Kalimantan Utara             117
# Aceh                         116
# Jambi                        116
# Gorontalo                    114
# Jawa Barat                   114
# Jawa Timur                   114
# DKI Jakarta                  113
# Sulawesi Utara               112
# Sulawesi Tengah              111
# Kalimantan Selatan           110
# Banten                       110
# Bali                         110
# Kalimantan Tengah            110
# Sumatera Utara               110
# Papua Barat                  107
# Kalimantan Barat             107
# DI Yogyakarta                106
# Sumatera Selatan             106
# Maluku Utara                 105
# Sulawesi Barat               105
# Bengkulu                     104
# Kepulauan Bangka Belitung    102
# Riau                         100
# Sumatera Barat                97
# ...

# %%
Province = data['Province'].value_counts()
Province_values = Province.values
labels = Province.index
plt.figure(figsize=(10, 16))
plt.pie(Province, labels=labels, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'red'])
plt.title('Province')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X = data.drop('Province', axis=1)  
y = data['Province']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X
# Out:
#       Year  Harvested Area    Production     Rainfall   Humidity  Temperature
# 0     2019     1424.293464  25801.764898  2831.560841  59.289787    28.910278
# 1     2020     6114.751121  44626.209626  1722.777453  62.244203    24.606217
# 2     2019     1660.768043  21617.397809  1306.531621  95.417902    27.800699
# 3     2022     3793.726252  17354.810069  2873.744139  54.669488    29.303221
# 4     2023     3969.911095  25785.067184   324.781118  67.921921    20.928729
# ...    ...             ...           ...          ...        ...          ...
# 3655  2018     8805.503426  10628.729763  2783.792600  79.582643    24.787319
# 3656  2018     3719.776568  12438.357384   439.951525  78.674428    30.863002
# 3657  2019     2981.478022  34566.552608   365.310355  60.881017    29.434494
# 3658  2019     3439.102170   4198.449067  1807.079109  57.084987    24.803592
# 3659  2023      479.125959  37050.675986   377.820711  55.616995    20.289727
#
# [3660 rows x 6 columns]

# %%
y
# Out:
# 0                      Aceh
# 1            Kepulauan Riau
# 2            Sulawesi Utara
# 3                Jawa Timur
# 4                     Jambi
#                ...
# 3655    Nusa Tenggara Timur
# 3656             Jawa Timur
# 3657             Jawa Barat
# 3658            DKI Jakarta
# 3659       Kalimantan Barat
# Name: Province, Length: 3660, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(data['Province'])
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
regressors = {
    "Random Forest": RandomForestRegressor(random_state=42, max_depth=10, min_samples_split=5, min_samples_leaf=4),
    "Decision Tree": DecisionTreeRegressor(random_state=42, max_depth=10),
    "Support Vector Machine": SVR(kernel='rbf'),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "AdaBoosting": AdaBoostRegressor(random_state=42),
    "xgboost":XGBRegressor(random_state=42, seed=42, n_estimators=200, subsample=0.7, colsample_bytree=0.7, max_depth=9, gamma=0.5, learning_rate=0.05, alpha=0.1, lambda_=1),
    "K-Nearest Neighbors": KNeighborsRegressor(n_neighbors=5),
    "Artificial Neural Networks": MLPRegressor(random_state=42, max_iter=1000, hidden_layer_sizes=(50,), alpha=0.1)
}

# %%
for name, reg in regressors.items():
    reg.fit(X_train_scaled, y_train_encoded)
    y_pred = reg.predict(X_test_scaled)
    mse = mean_squared_error(y_test_encoded, y_pred)
    mae = mean_absolute_error(y_test_encoded, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test_encoded, y_pred)
    print(f'{name} Performance:')
    print(f' - Mean Absolute Error (MAE): {mae:.4f}')
    print(f' - Mean Squared Error (MSE): {mse:.4f}')
    print(f' - Root Mean Squared Error (RMSE): {rmse:.4f}')
    print(f' - R-squared (R2): {r2:.4f}\n')
# Out:
# Random Forest Performance:
#  - Mean Absolute Error (MAE): 2.1140
#  - Mean Squared Error (MSE): 8.3730
#  - Root Mean Squared Error (RMSE): 2.8936
#  - R-squared (R2): 0.9106
#
# Decision Tree Performance:
#  - Mean Absolute Error (MAE): 2.3331
#  - Mean Squared Error (MSE): 16.6510
#  - Root Mean Squared Error (RMSE): 4.0806
#  - R-squared (R2): 0.8221
#
# Support Vector Machine Performance:
#  - Mean Absolute Error (MAE): 5.9132
#  - Mean Squared Error (MSE): 65.3663
#  - Root Mean Squared Error (RMSE): 8.0849
#  - R-squared (R2): 0.3017
#
# Gradient Boosting Performance:
#  - Mean Absolute Error (MAE): 3.6249
#  - Mean Squared Error (MSE): 19.8145
#  - Root Mean Squared Error (RMSE): 4.4513
#  - R-squared (R2): 0.7883
#
# AdaBoosting Performance:
#  - Mean Absolute Error (MAE): 7.6264
#  - Mean Squared Error (MSE): 81.9524
#  - Root Mean Squared Error (RMSE): 9.0528
#  - R-squared (R2): 0.1246
#
# xgboost Performance:
#  - Mean Absolute Error (MAE): 0.1598
# ...

# %%
import time
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = XGBRegressor(random_state=42, seed=42, n_estimators=200, subsample=0.7, colsample_bytree=0.7, max_depth=9, gamma=0.5, learning_rate=0.05, alpha=0.1, lambda_=1)
start = time.time()
model.fit(X_train_scaled, y_train_encoded)
end = time.time()
print("Run Time: %f" % (end - start))
y_pred = model.predict(X_test_scaled)
mae = mean_absolute_error(y_test_encoded, y_pred)
mse = mean_squared_error(y_test_encoded, y_pred)
rmse = mean_squared_error(y_test_encoded, y_pred, squared=False)
r2 = r2_score(y_test_encoded, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'R-squared (R2): {r2:.4f}')
# Out:
# Run Time: 0.276523
# Mean Absolute Error (MAE): 0.1598
# Mean Squared Error (MSE): 0.0432
# Root Mean Squared Error (RMSE): 0.2078
# R-squared (R2): 0.9995
